# %% [raw]
# '''
#
#  similar_images_AE.py (author: Anson Wong / git: ankonzoid)
#
#  Image similarity recommender system using an autoencoder-clustering model.
#
#  Autoencoder method:
#   1) Train an autoencoder (simple/Conv) on training images in 'db/images_training'
#   2) Saves trained autoencoder, encoder, and decoder to 'db/models'
#
#  Clustering method:
#   3) Using our trained encoder in 'db/models', we encode inventory images in 'db/images_inventory'
#   4) Train kNN model using encoded inventory images
#   5) Encode query images in 'query', and predict their NN using our trained kNN model
#   6) Compute a score for each inventory encoding relative to our query encoding (centroid/closest)
#   7) Make k-recommendations by cloning top-k inventory images into 'answer'
#
# '''

# %%
import sys, os, shutil
import numpy as np
sys.path.append("src")
from autoencoders.AE import AE
from clustering.KNN import KNearestNeighbours
from utilities.image_utilities import ImageUtils
from utilities.sorting import find_topk_unique
from utilities.plot_utilities import PlotUtils
# Out:
# /Users/bpadalkar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# ========================================
# Set run settings
# ========================================

# Choose autoencoder model
#model_name = "simpleAE"
model_name = "convAE"
process_and_save_images = True  # image preproc: resize images and save?
train_autoencoder = True  # train from scratch?

# ========================================
# Automated pre-processing
# ========================================
##   Set flatten properties   ###
if model_name == "simpleAE":
    flatten_before_encode = True
    flatten_after_encode = False
elif model_name == "convAE":
    flatten_before_encode = False
    flatten_after_encode = True
else:
    raise Exception("Invalid model name which is not simpleAE/convAE")

img_shape = (100, 100)  # force resize -> (ypixels, xpixels)
ratio_train_test = 0.8
seed = 100

loss = "binary_crossentropy"
optimizer = "adam"
n_epochs = 50
batch_size = 256

save_reconstruction_on_load_model = True


###   KNN training parameters   ###
n_neighbors = 5  # number of nearest neighbours
metric = "cosine"  # kNN metric (cosine only compatible with brute force)
algorithm = "brute"  # search algorithm
recommendation_method = 2  # 1 = centroid kNN, 2 = all points kNN
output_mode = 1  # 1 = output plot, 2 = output inventory db image clones

# %%
# ========================================
# Generate expected file/folder paths and settings
# ========================================
# Assume project root directory to be directory of file
project_root = os.path.dirname('.')
print("Project root: {0}".format(project_root))

# Query and answer folder
query_dir = os.path.join(project_root, 'test-images')
answer_dir = os.path.join(project_root, 'output')

# In database folder
db_dir = os.path.join(project_root, 'food-101/images')
img_train_raw_file = os.path.join('food-101/meta/small_train.txt')
img_inventory_raw_file = os.path.join('food-101/meta/small_test.txt')
img_train_dir = os.path.join('train-images')
img_inventory_dir = os.path.join('test-images')

# Run output
models_dir = os.path.join('models')

# Set info file
info = {
    # Run settings
    "img_shape": img_shape,
    "flatten_before_encode": flatten_before_encode,
    "flatten_after_encode": flatten_after_encode,

    # Directories
    "query_dir": query_dir,
    "answer_dir": answer_dir,

    "img_train_raw_file": img_train_raw_file,
    "img_inventory_raw_file": img_inventory_raw_file,
    "img_train_dir": img_train_dir,
    "img_inventory_dir": img_inventory_dir,

    # Run output
    "models_dir": models_dir
}
# Out:
# Project root:

# %%
# Initialize image utilities (and register encoder)
IU = ImageUtils()
IU.configure(info)

# Initialize plot utilities
PU = PlotUtils()

# ========================================
#
# Pre-process save/load training and inventory images
#
# ========================================

# Process and save
if process_and_save_images:

    # Training images
    IU.raw2resized_load_save(raw_dir=img_train_raw_file,
                             processed_dir=img_train_dir,
                             img_shape=img_shape)
    # Inventory images
    IU.raw2resized_load_save(raw_dir=img_inventory_raw_file,
                             processed_dir=img_inventory_dir,
                             img_shape=img_shape)
# Out:
# food-101/meta/small_train.txt
# [1/200] Resized and saved to 'train-images/apple_pie_1005649_resized.jpg'...
# [2/200] Resized and saved to 'train-images/apple_pie_1014775_resized.jpg'...
# [3/200] Resized and saved to 'train-images/apple_pie_1026328_resized.jpg'...
# [4/200] Resized and saved to 'train-images/apple_pie_1028787_resized.jpg'...
# [5/200] Resized and saved to 'train-images/apple_pie_1043283_resized.jpg'...
# [6/200] Resized and saved to 'train-images/apple_pie_1050519_resized.jpg'...
# [7/200] Resized and saved to 'train-images/apple_pie_1057749_resized.jpg'...
# [8/200] Resized and saved to 'train-images/apple_pie_1057810_resized.jpg'...
# [9/200] Resized and saved to 'train-images/apple_pie_1072416_resized.jpg'...
# [10/200] Resized and saved to 'train-images/apple_pie_1074856_resized.jpg'...
# [11/200] Resized and saved to 'train-images/apple_pie_1074942_resized.jpg'...
# [12/200] Resized and saved to 'train-images/apple_pie_1076891_resized.jpg'...
# [13/200] Resized and saved to 'train-images/apple_pie_1077610_resized.jpg'...
# [14/200] Resized and saved to 'train-images/apple_pie_1077964_resized.jpg'...
# [15/200] Resized and saved to 'train-images/apple_pie_1088809_resized.jpg'...
# [16/200] Resized and saved to 'train-images/apple_pie_1097378_resized.jpg'...
# [17/200] Resized and saved to 'train-images/apple_pie_1103795_resized.jpg'...
# [18/200] Resized and saved to 'train-images/apple_pie_1109597_resized.jpg'...
# [19/200] Resized and saved to 'train-images/apple_pie_1111062_resized.jpg'...
# [20/200] Resized and saved to 'train-images/apple_pie_1112300_resized.jpg'...
# [21/200] Resized and saved to 'train-images/baby_back_ribs_1007102_resized.jpg'...
# [22/200] Resized and saved to 'train-images/baby_back_ribs_1007272_resized.jpg'...
# [23/200] Resized and saved to 'train-images/baby_back_ribs_1008749_resized.jpg'...
# [24/200] Resized and saved to 'train-images/baby_back_ribs_1009028_resized.jpg'...
# [25/200] Resized and saved to 'train-images/baby_back_ribs_1031072_resized.jpg'...
# [26/200] Resized and saved to 'train-images/baby_back_ribs_1031112_resized.jpg'...
# /Users/bpadalkar/anaconda3/lib/python3.6/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /Users/bpadalkar/anaconda3/lib/python3.6/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#
# [32/49] Resized and saved to 'test-images/beignets_1017820_resized.jpg'...
# [33/49] Resized and saved to 'test-images/beignets_1022290_resized.jpg'...
# [34/49] Resized and saved to 'test-images/beignets_1036242_resized.jpg'...
# [35/49] Resized and saved to 'test-images/bibimbap_1001113_resized.jpg'...
# [36/49] Resized and saved to 'test-images/bibimbap_1004374_resized.jpg'...
# [37/49] Resized and saved to 'test-images/bibimbap_1004963_resized.jpg'...
# [38/49] Resized and saved to 'test-images/bibimbap_1007274_resized.jpg'...
# [39/49] Resized and saved to 'test-images/bibimbap_1018560_resized.jpg'...
# [40/49] Resized and saved to 'test-images/bread_pudding_1005036_resized.jpg'...
# [41/49] Resized and saved to 'test-images/bread_pudding_1042213_resized.jpg'...
# [42/49] Resized and saved to 'test-images/bread_pudding_1084705_resized.jpg'...
# [43/49] Resized and saved to 'test-images/bread_pudding_1105517_resized.jpg'...
# [44/49] Resized and saved to 'test-images/bread_pudding_1119079_resized.jpg'...
# [45/49] Resized and saved to 'test-images/breakfast_burrito_1000920_resized.jpg'...
# [46/49] Resized and saved to 'test-images/breakfast_burrito_1015606_resized.jpg'...
# [47/49] Resized and saved to 'test-images/breakfast_burrito_1017114_resized.jpg'...
# [48/49] Resized and saved to 'test-images/breakfast_burrito_1025868_resized.jpg'...
# [49/49] Resized and saved to 'test-images/breakfast_burrito_1036087_resized.jpg'...

# %%
# ========================================
#
# Train autoencoder
#
# ========================================

# Set up autoencoder base class
MODEL = AE()

MODEL.configure(model_name=model_name)

if train_autoencoder:

    print("Training the autoencoder...")

    # Generate naming conventions
    dictfn = MODEL.generate_naming_conventions(model_name, models_dir)
    MODEL.start_report(dictfn)  # start report

    # Load training images to memory (resizes when necessary)
    x_data_all, all_filenames = \
        IU.raw2resizednorm_load(raw_dir=img_train_dir, img_shape=img_shape)
    print("\nAll data:")
    print(" x_data_all.shape = {0}\n".format(x_data_all.shape))

    # Split images to training and validation set
    x_data_train, x_data_test, index_train, index_test = \
        IU.split_train_test(x_data_all, ratio_train_test, seed)
    print("\nSplit data:")
    print("x_data_train.shape = {0}".format(x_data_train.shape))
    print("x_data_test.shape = {0}\n".format(x_data_test.shape))

    # Flatten data if necessary
    if flatten_before_encode:
        x_data_train = IU.flatten_img_data(x_data_train)
        x_data_test = IU.flatten_img_data(x_data_test)
        print("\nFlattened data:")
        print("x_data_train.shape = {0}".format(x_data_train.shape))
        print("x_data_test.shape = {0}\n".format(x_data_test.shape))

    # Set up architecture and compile model
    MODEL.set_arch(input_shape=x_data_train.shape[1:],
                   output_shape=x_data_train.shape[1:])
    MODEL.compile(loss=loss, optimizer=optimizer)
    MODEL.append_arch_report(dictfn)  # append to report

    # Train model
    MODEL.append_message_report(dictfn, "Start training")  # append to report
    MODEL.train(x_data_train, x_data_test,
                n_epochs=n_epochs, batch_size=batch_size)
    MODEL.append_message_report(dictfn, "End training")  # append to report

    # Save model to file
    MODEL.save_model(dictfn)

    # Save reconstructions to file
    MODEL.plot_save_reconstruction(x_data_test, img_shape, dictfn, n_plot=10)

else:

    # Generate naming conventions
    dictfn = MODEL.generate_naming_conventions(model_name, models_dir)

    # Load models
    MODEL.load_model(dictfn)

    # Compile model
    MODEL.compile(loss=loss, optimizer=optimizer)

    # Save reconstructions to file
    if save_reconstruction_on_load_model:
        x_data_all, all_filenames = \
            IU.raw2resizednorm_load(raw_dir=img_train_dir, img_shape=img_shape)
        if flatten_before_encode:
            x_data_all = IU.flatten_img_data(x_data_all)
        MODEL.plot_save_reconstruction(x_data_all, img_shape, dictfn, n_plot=10)
# Out:
# Training the autoencoder...
# [1/200] Loaded and processed 'train-images/beignets_1026640_resized.jpg'...
# [2/200] Loaded and processed 'train-images/beignets_1011780_resized.jpg'...
# [3/200] Loaded and processed 'train-images/beignets_105576_resized.jpg'...
# [4/200] Loaded and processed 'train-images/beet_salad_1021189_resized.jpg'...
# [5/200] Loaded and processed 'train-images/breakfast_burrito_1058434_resized.jpg'...
# [6/200] Loaded and processed 'train-images/apple_pie_1043283_resized.jpg'...
# [7/200] Loaded and processed 'train-images/bread_pudding_1052635_resized.jpg'...
# [8/200] Loaded and processed 'train-images/beignets_1040454_resized.jpg'...
# [9/200] Loaded and processed 'train-images/beef_tartare_1107638_resized.jpg'...
# [10/200] Loaded and processed 'train-images/beef_carpaccio_1032760_resized.jpg'...
# [11/200] Loaded and processed 'train-images/apple_pie_1111062_resized.jpg'...
# [12/200] Loaded and processed 'train-images/baklava_1086727_resized.jpg'...
# [13/200] Loaded and processed 'train-images/baby_back_ribs_1007272_resized.jpg'...
# [14/200] Loaded and processed 'train-images/beet_salad_1016430_resized.jpg'...
# [15/200] Loaded and processed 'train-images/beignets_1064858_resized.jpg'...
# [16/200] Loaded and processed 'train-images/beet_salad_1080241_resized.jpg'...
# [17/200] Loaded and processed 'train-images/baklava_1045575_resized.jpg'...
# [18/200] Loaded and processed 'train-images/baklava_1109957_resized.jpg'...
# [19/200] Loaded and processed 'train-images/beef_tartare_1056987_resized.jpg'...
# [20/200] Loaded and processed 'train-images/bibimbap_1009730_resized.jpg'...
# [21/200] Loaded and processed 'train-images/beef_tartare_108575_resized.jpg'...
# [22/200] Loaded and processed 'train-images/baby_back_ribs_1007102_resized.jpg'...
# [23/200] Loaded and processed 'train-images/bibimbap_1039518_resized.jpg'...
# [24/200] Loaded and processed 'train-images/apple_pie_1097378_resized.jpg'...
# [25/200] Loaded and processed 'train-images/beet_salad_104294_resized.jpg'...
# [26/200] Loaded and processed 'train-images/breakfast_burrito_1053966_resized.jpg'...
# [27/200] Loaded and processed 'train-images/apple_pie_1077964_resized.jpg'...
# [28/200] Loaded and processed 'train-images/beef_tartare_1046416_resized.jpg'...
# [29/200] Loaded and processed 'train-images/bibimbap_1036589_resized.jpg'...
# [30/200] Loaded and processed 'train-images/bibimbap_1002297_resized.jpg'...
# [31/200] Loaded and processed 'train-images/baklava_1014880_resized.jpg'...
# [32/200] Loaded and processed 'train-images/beignets_1034823_resized.jpg'...
# [33/200] Loaded and processed 'train-images/bread_pudding_100939_resized.jpg'...
# [34/200] Loaded and processed 'train-images/beef_carpaccio_103294_resized.jpg'...
# [195/200] Loaded and processed 'train-images/beef_carpaccio_1091862_resized.jpg'...
# [196/200] Loaded and processed 'train-images/breakfast_burrito_1040049_resized.jpg'...
# [197/200] Loaded and processed 'train-images/beignets_1048606_resized.jpg'...
# [198/200] Loaded and processed 'train-images/beet_salad_1005864_resized.jpg'...
# [199/200] Loaded and processed 'train-images/baby_back_ribs_1070017_resized.jpg'...
# [200/200] Loaded and processed 'train-images/bibimbap_1046141_resized.jpg'...
#
# All data:
#  x_data_all.shape = (200, 100, 100, 3)
#
#
# Split data:
# x_data_train.shape = (165, 100, 100, 3)
# x_data_test.shape = (35, 100, 100, 3)
# autoencoder.summary():
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 100, 100, 3)       435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# encoder.summary():
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 8)         0
# =================================================================
# Total params: 2,192
# Trainable params: 2,192
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# decoder.summary():
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 13, 13, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 100, 100, 3)       435
# =================================================================
# Total params: 2,771
# Trainable params: 2,771
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 165 samples, validate on 35 samples
# Epoch 1/50
# 165/165 [==============================] - 3s 17ms/step - loss: 0.6933 - val_loss: 0.6934
# Epoch 2/50
# 165/165 [==============================] - 2s 14ms/step - loss: 0.6924 - val_loss: 0.6926
# Epoch 3/50
# 165/165 [==============================] - 2s 13ms/step - loss: 0.6918 - val_loss: 0.6918
# Epoch 4/50
# 165/165 [==============================] - 3s 17ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 5/50
# 165/165 [==============================] - 2s 13ms/step - loss: 0.6902 - val_loss: 0.6901
# Epoch 6/50
# 165/165 [==============================] - 2s 14ms/step - loss: 0.6892 - val_loss: 0.6891
# Epoch 7/50
# 165/165 [==============================] - 2s 13ms/step - loss: 0.6882 - val_loss: 0.6880
# Epoch 8/50
# 165/165 [==============================] - 3s 15ms/step - loss: 0.6870 - val_loss: 0.6868
# Epoch 9/50
# Epoch 39/50
# 165/165 [==============================] - 2s 12ms/step - loss: 0.6174 - val_loss: 0.6140
# Epoch 40/50
# 165/165 [==============================] - 2s 12ms/step - loss: 0.6122 - val_loss: 0.6090
# Epoch 41/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.6080 - val_loss: 0.6074
# Epoch 42/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.6051 - val_loss: 0.6010
# Epoch 43/50
# 165/165 [==============================] - 2s 10ms/step - loss: 0.6015 - val_loss: 0.5984
# Epoch 44/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.5972 - val_loss: 0.5952
# Epoch 45/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.5944 - val_loss: 0.5911
# Epoch 46/50
# 165/165 [==============================] - 2s 10ms/step - loss: 0.5929 - val_loss: 0.5918
# Epoch 47/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.5908 - val_loss: 0.5855
# Epoch 48/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.5872 - val_loss: 0.5830
# Epoch 49/50
# 165/165 [==============================] - 2s 10ms/step - loss: 0.5856 - val_loss: 0.5842
# Epoch 50/50
# 165/165 [==============================] - 2s 11ms/step - loss: 0.5849 - val_loss: 0.5787
# Saving models...

# %%
# ========================================
#
# Perform clustering recommendation
#
# ========================================

# Load inventory images to memory (resizes when necessary)
x_data_inventory, inventory_filenames = \
    IU.raw2resizednorm_load(raw_dir=img_inventory_dir, img_shape=img_shape)
print("\nx_data_inventory.shape = {0}\n".format(x_data_inventory.shape))

# Explictly assign loaded encoder
encoder = MODEL.encoder

# Encode our data, then flatten to encoding dimensions
# We switch names for simplicity: inventory -> train, query -> test
print("Encoding data and flatten its encoding dimensions...")
if flatten_before_encode:  # Flatten the data before encoder prediction
    x_data_inventory = IU.flatten_img_data(x_data_inventory)

x_train_kNN = encoder.predict(x_data_inventory)

if flatten_after_encode:  # Flatten the data after encoder prediction
    x_train_kNN = IU.flatten_img_data(x_train_kNN)

print("\nx_train_kNN.shape = {0}\n".format(x_train_kNN.shape))


# =================================
# Train kNN model
# =================================
print("Performing kNN to locate nearby items to user centroid points...")
EMB = KNearestNeighbours()  # initialize embedding kNN class
EMB.compile(n_neighbors=n_neighbors, algorithm=algorithm, metric=metric)  # compile kNN model
EMB.fit(x_train_kNN)  # fit kNN


# =================================
# Perform kNN on query images
# =================================

# Read items in query folder
print("Reading query images from query folder: {0}".format(query_dir))

# Load query images to memory (resizes when necessary)
x_data_query, query_filenames = \
    IU.raw2resizednorm_load(raw_dir=query_dir,
                            img_shape=img_shape)
n_query = len(x_data_query)
print("\nx_data_query.shape = {0}\n".format(x_data_query.shape))

# Encode query images
if flatten_before_encode:  # Flatten the data before encoder prediction
    x_data_query = IU.flatten_img_data(x_data_query)

# Perform kNN on each query image
for ind_query in range(n_query):

    # Encode query image (and flatten if needed)
    newshape = (1,) + x_data_query[ind_query].shape
    x_query_i_use = x_data_query[ind_query].reshape(newshape)
    x_test_kNN = encoder.predict(x_query_i_use)
    query_filename = query_filenames[ind_query]

    name, tag = IU.extract_name_tag2(query_filename)  # extract name and tag
    print("({0}/{1}) Performing kNN on query '{2}'...".format(ind_query+1, n_query, name))

    if flatten_after_encode:  # Flatten the data after encoder prediction
        x_test_kNN = IU.flatten_img_data(x_test_kNN)

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Compute distances and indices for recommendation
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    if recommendation_method == 1:  # kNN centroid transactions

        # Compute centroid point of the query encoding vectors (equal weights)
        x_test_kNN_centroid = np.mean(x_test_kNN, axis = 0)
        # Find nearest neighbours to centroid point
        distances, indices = EMB.predict(np.array([x_test_kNN_centroid]))

    elif recommendation_method == 2:  # kNN all transactions

        # Find k nearest neighbours to all transactions, then flatten the distances and indices
        distances, indices = EMB.predict(x_test_kNN)
        distances = distances.flatten()
        indices = indices.flatten()
        # Pick k unique training indices which have the shortest distances any transaction point
        indices, distances = find_topk_unique(indices, distances, n_neighbors)

    else:
        raise Exception("Invalid method for making recommendations")


    print("  x_test_kNN.shape = {0}".format(x_test_kNN.shape))
    print("  distances = {0}".format(distances))
    print("  indices = {0}\n".format(indices))

    # =============================================
    #
    # Output results
    #
    # =============================================
    if output_mode == 1:

        result_filename = os.path.join(answer_dir, "result_" + name + ".png")

        x_query_plot = x_data_query[ind_query].reshape((-1, img_shape[0], img_shape[1], 3))
        x_answer_plot = x_data_inventory[indices].reshape((-1, img_shape[0], img_shape[1], 3))
        PU.plot_query_answer(x_query=x_query_plot,
                             x_answer=x_answer_plot,
                             filename=result_filename)

    elif output_mode == 2:

        # Clone answer file to answer folder
        # Make k-recommendations and clone most similar inventory images to answer dir
        print("Cloning k-recommended inventory images to answer folder '{0}'...".format(answer_dir))
        for i, (index, distance) in enumerate(zip(indices, distances)):
            print("\n({0}): index = {1}".format(i, index))
            print("({0}): distance = {1}\n".format(i, distance))

            for k_rec, ind in enumerate(index):

                # Extract inventory filename
                inventory_filename = inventory_filenames[ind]

                # Extract answer filename
                name, tag = IU.extract_name_tag(inventory_filename)
                answer_filename = os.path.join(answer_dir, name + '.' + tag)

                print("Cloning '{0}' to answer directory...".format(inventory_filename))
                shutil.copy(inventory_filename, answer_filename)

    else:
        raise Exception("Invalid output mode given!")
# Out:
# [1/49] Loaded and processed 'test-images/beet_salad_1054193_resized.jpg'...
# [2/49] Loaded and processed 'test-images/beef_tartare_1029120_resized.jpg'...
# [3/49] Loaded and processed 'test-images/breakfast_burrito_1000920_resized.jpg'...
# [4/49] Loaded and processed 'test-images/beef_carpaccio_1056550_resized.jpg'...
# [5/49] Loaded and processed 'test-images/baby_back_ribs_1086617_resized.jpg'...
# [6/49] Loaded and processed 'test-images/baby_back_ribs_1005066_resized.jpg'...
# [7/49] Loaded and processed 'test-images/breakfast_burrito_1015606_resized.jpg'...
# [8/49] Loaded and processed 'test-images/beignets_1022290_resized.jpg'...
# [9/49] Loaded and processed 'test-images/beef_carpaccio_1073326_resized.jpg'...
# [10/49] Loaded and processed 'test-images/baklava_104446_resized.jpg'...
# [11/49] Loaded and processed 'test-images/breakfast_burrito_1025868_resized.jpg'...
# [12/49] Loaded and processed 'test-images/beet_salad_1062993_resized.jpg'...
# [13/49] Loaded and processed 'test-images/bibimbap_1004374_resized.jpg'...
# [14/49] Loaded and processed 'test-images/baklava_1028777_resized.jpg'...
# [15/49] Loaded and processed 'test-images/bread_pudding_1005036_resized.jpg'...
# [16/49] Loaded and processed 'test-images/apple_pie_101251_resized.jpg'...
# [17/49] Loaded and processed 'test-images/breakfast_burrito_1036087_resized.jpg'...
# [18/49] Loaded and processed 'test-images/beef_carpaccio_1012548_resized.jpg'...
# [19/49] Loaded and processed 'test-images/bibimbap_1001113_resized.jpg'...
# [20/49] Loaded and processed 'test-images/baby_back_ribs_1058654_resized.jpg'...
# [21/49] Loaded and processed 'test-images/beef_tartare_1066933_resized.jpg'...
# [22/49] Loaded and processed 'test-images/bibimbap_1018560_resized.jpg'...
# [23/49] Loaded and processed 'test-images/beef_tartare_101073_resized.jpg'...
# [24/49] Loaded and processed 'test-images/breakfast_burrito_1017114_resized.jpg'...
# [25/49] Loaded and processed 'test-images/apple_pie_1034399_resized.jpg'...
# [26/49] Loaded and processed 'test-images/beet_salad_1014948_resized.jpg'...
# [27/49] Loaded and processed 'test-images/baklava_1062541_resized.jpg'...
# [28/49] Loaded and processed 'test-images/baklava_1029051_resized.jpg'...
# [29/49] Loaded and processed 'test-images/bibimbap_1004963_resized.jpg'...
# [30/49] Loaded and processed 'test-images/beef_tartare_1030025_resized.jpg'...
# [31/49] Loaded and processed 'test-images/bibimbap_1007274_resized.jpg'...
# [32/49] Loaded and processed 'test-images/apple_pie_1038694_resized.jpg'...
# [33/49] Loaded and processed 'test-images/apple_pie_103801_resized.jpg'...
# [34/49] Loaded and processed 'test-images/baklava_1067270_resized.jpg'...
# [35/49] Loaded and processed 'test-images/beef_carpaccio_100853_resized.jpg'...
# [36/49] Loaded and processed 'test-images/beignets_1036242_resized.jpg'...
# [37/49] Loaded and processed 'test-images/bread_pudding_1119079_resized.jpg'...
# [38/49] Loaded and processed 'test-images/bread_pudding_1105517_resized.jpg'...
# [39/49] Loaded and processed 'test-images/baby_back_ribs_1022479_resized.jpg'...
# [40/49] Loaded and processed 'test-images/beignets_1002850_resized.jpg'...
# [41/49] Loaded and processed 'test-images/beignets_1017820_resized.jpg'...
# [42/49] Loaded and processed 'test-images/apple_pie_1011328_resized.jpg'...
# [43/49] Loaded and processed 'test-images/bread_pudding_1042213_resized.jpg'...
# [44/49] Loaded and processed 'test-images/bread_pudding_1084705_resized.jpg'...
# [45/49] Loaded and processed 'test-images/beef_carpaccio_1044312_resized.jpg'...
# [46/49] Loaded and processed 'test-images/baby_back_ribs_1074480_resized.jpg'...
# [47/49] Loaded and processed 'test-images/beef_tartare_1031053_resized.jpg'...
# [48/49] Loaded and processed 'test-images/beet_salad_1030522_resized.jpg'...
# [49/49] Loaded and processed 'test-images/beet_salad_1071243_resized.jpg'...
#
# x_data_inventory.shape = (49, 100, 100, 3)
#
# Encoding data and flatten its encoding dimensions...
#
# x_train_kNN.shape = (49, 1352)
#
# Performing kNN to locate nearby items to user centroid points...
# Reading query images from query folder: test-images
# [41/49] Loaded and processed 'test-images/beignets_1017820_resized.jpg'...
# [42/49] Loaded and processed 'test-images/apple_pie_1011328_resized.jpg'...
# [43/49] Loaded and processed 'test-images/bread_pudding_1042213_resized.jpg'...
# [44/49] Loaded and processed 'test-images/bread_pudding_1084705_resized.jpg'...
# [45/49] Loaded and processed 'test-images/beef_carpaccio_1044312_resized.jpg'...
# [46/49] Loaded and processed 'test-images/baby_back_ribs_1074480_resized.jpg'...
# [47/49] Loaded and processed 'test-images/beef_tartare_1031053_resized.jpg'...
# [48/49] Loaded and processed 'test-images/beet_salad_1030522_resized.jpg'...
# [49/49] Loaded and processed 'test-images/beet_salad_1071243_resized.jpg'...
#
# x_data_query.shape = (49, 100, 100, 3)
#
# (1/49) Performing kNN on query 'beet_salad_1054193_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.05930316 0.05971837 0.06153703 0.06250393]]
#   indices = [[ 0 10 37 43 15]]
#
# (2/49) Performing kNN on query 'beef_tartare_1029120_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.04640228 0.07022679 0.07164842 0.07382685]]
#   indices = [[ 1 23 13 45 16]]
# (3/49) Performing kNN on query 'breakfast_burrito_1000920_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.02144992 0.035887   0.03782392 0.03840441]]
#   indices = [[ 2 15 33 42 34]]
#
# (4/49) Performing kNN on query 'beef_carpaccio_1056550_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.10206604 0.10392487 0.10596406 0.10741198]]
#   indices = [[ 3 17  1 46  9]]
#
# (5/49) Performing kNN on query 'baby_back_ribs_1086617_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[4.1723251e-07 7.0270240e-02 8.1205010e-02 8.6756825e-02 8.9550018e-02]]
#   indices = [[ 4 39 18 30 15]]
#
# (6/49) Performing kNN on query 'baby_back_ribs_1005066_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.03596115 0.03949136 0.0443058  0.04733604]]
#   indices = [[ 5 34 20 15 33]]
#
# (7/49) Performing kNN on query 'breakfast_burrito_1015606_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.05275381 0.05290473 0.05712461 0.06401974]]
#   indices = [[ 6 17 15 39 46]]
#
# (8/49) Performing kNN on query 'beignets_1022290_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.02821845 0.03498757 0.04394078 0.04645646]]
#   indices = [[ 7 31 16 33 20]]
#
# (9/49) Performing kNN on query 'beef_carpaccio_1073326_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.0575974  0.05794507 0.06278121 0.06458282]]
#   indices = [[ 8 11 45  7 16]]
#
# (10/49) Performing kNN on query 'baklava_104446_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[3.5762787e-07 6.2252522e-02 7.1159184e-02 7.4800372e-02 7.8396142e-02]]
#   indices = [[ 9 15 20 13 17]]
#
# (11/49) Performing kNN on query 'breakfast_burrito_1025868_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.04376978 0.04811877 0.04944396 0.05466962]]
#   indices = [[10 43 35 15 40]]
#
# (12/49) Performing kNN on query 'beet_salad_1062993_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.0472753  0.05147463 0.05448312 0.05463803]]
#   indices = [[11 48 20 45 25]]
#
# (13/49) Performing kNN on query 'bibimbap_1004374_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.3841858e-07 4.2282283e-02 4.6997964e-02 4.7649324e-02 4.9406946e-02]]
#   indices = [[12 15  2 34 40]]
#
# (14/49) Performing kNN on query 'baklava_1028777_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.9802322e-07 2.9976964e-02 3.3100128e-02 3.5900652e-02 3.8327217e-02]]
#   indices = [[13 16 15 34 33]]
#
# (15/49) Performing kNN on query 'bread_pudding_1005036_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.03937346 0.04183221 0.04819536 0.05384535]]
#   indices = [[14 38 15 43  2]]
#
# (16/49) Performing kNN on query 'apple_pie_101251_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.9802322e-07 2.1449924e-02 2.6380658e-02 2.9251695e-02 2.9785693e-02]]
#   indices = [[15  2 35 33 20]]
#
# (17/49) Performing kNN on query 'breakfast_burrito_1036087_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.3841858e-07 2.2128940e-02 2.5986493e-02 2.9976964e-02 3.2231510e-02]]
#   indices = [[16 31 33 13 34]]
#
# (18/49) Performing kNN on query 'beef_carpaccio_1012548_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.04743004 0.05275381 0.05411005 0.057652  ]]
#   indices = [[17 15  6  2 39]]
#
# (19/49) Performing kNN on query 'bibimbap_1001113_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.06522107 0.06720978 0.06961441 0.07168591]]
#   indices = [[18 39 30 15 35]]
#
# (20/49) Performing kNN on query 'baby_back_ribs_1058654_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.05398804 0.0638712  0.06489784 0.06664836]]
#   indices = [[19 15  2 33 45]]
# /Users/bpadalkar/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# (21/49) Performing kNN on query 'beef_tartare_1066933_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.9802322e-07 2.5573730e-02 2.9785693e-02 3.6514401e-02 3.7221313e-02]]
#   indices = [[20 34 15 25 45]]
#
# (22/49) Performing kNN on query 'bibimbap_1018560_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.12111974 0.13134426 0.1333031  0.1376512 ]]
#   indices = [[21 17 44  6 14]]
#
# (23/49) Performing kNN on query 'beef_tartare_101073_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.1920929e-07 5.2921712e-02 6.0909629e-02 6.4144969e-02 7.6487005e-02]]
#   indices = [[22 43 40 15 41]]
#
# (24/49) Performing kNN on query 'breakfast_burrito_1017114_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.04640228 0.05659854 0.05758482 0.06039661]]
#   indices = [[23  1  2 40 15]]
#
# (25/49) Performing kNN on query 'apple_pie_1034399_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.09004927 0.09540856 0.095581   0.09974587]]
#   indices = [[24 40 15 13 12]]
#
# (26/49) Performing kNN on query 'beet_salad_1014948_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.1920929e-07 3.0948877e-02 3.6514401e-02 4.1124046e-02 4.1710854e-02]]
#   indices = [[25 34 20 45 48]]
#
# (27/49) Performing kNN on query 'baklava_1062541_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.3841858e-07 3.5928667e-02 4.1438222e-02 4.2975307e-02 4.5657814e-02]]
#   indices = [[26 15 20 35  2]]
#
# (28/49) Performing kNN on query 'baklava_1029051_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.7881393e-07 8.1404924e-02 8.4881246e-02 8.5543752e-02 8.6504340e-02]]
#   indices = [[27 39 35  2 18]]
#
# (29/49) Performing kNN on query 'bibimbap_1004963_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.10119855 0.11609191 0.11712039 0.121086  ]]
#   indices = [[28 33 45 15 16]]
#
# (30/49) Performing kNN on query 'beef_tartare_1030025_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.07481098 0.07573628 0.08364373 0.08861357]]
#   indices = [[29 17 23 15 46]]
#
# (31/49) Performing kNN on query 'bibimbap_1007274_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.1920929e-07 5.8753133e-02 6.0977578e-02 6.5935135e-02 6.7209780e-02]]
#   indices = [[30 15 14 40 18]]
#
# (32/49) Performing kNN on query 'apple_pie_1038694_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[3.5762787e-07 2.2128940e-02 2.5129378e-02 2.8218448e-02 3.7315905e-02]]
#   indices = [[31 16 33  7 34]]
#
# (33/49) Performing kNN on query 'apple_pie_103801_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.09981769 0.10885262 0.10990965 0.11833   ]]
#   indices = [[32  4 27 30 18]]
#
# (34/49) Performing kNN on query 'baklava_1067270_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.02512938 0.02598649 0.02925169 0.03557998]]
#   indices = [[33 31 16 15 34]]
#
# (35/49) Performing kNN on query 'beef_carpaccio_100853_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.1920929e-07 2.5573730e-02 3.0948877e-02 3.1592786e-02 3.2231510e-02]]
#   indices = [[34 20 25 15 16]]
#
# (36/49) Performing kNN on query 'beignets_1036242_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[5.9604645e-08 2.6380658e-02 4.0422738e-02 4.1857719e-02 4.2571664e-02]]
#   indices = [[35 15 13  2 20]]
#
# (37/49) Performing kNN on query 'bread_pudding_1119079_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.06124634 0.06679535 0.07279944 0.07523847]]
#   indices = [[36 44 14 37  0]]
#
# (38/49) Performing kNN on query 'bread_pudding_1105517_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.05412507 0.05971837 0.07097924 0.07279944]]
#   indices = [[37 44  0 10 36]]
#
# (39/49) Performing kNN on query 'baby_back_ribs_1022479_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[5.9604645e-08 3.9373457e-02 4.6929359e-02 4.8808932e-02 4.9787104e-02]]
#   indices = [[38 14 43 42 15]]
#
# (40/49) Performing kNN on query 'beignets_1002850_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[5.9604645e-08 4.4784546e-02 5.0317347e-02 5.5074334e-02 5.5888653e-02]]
#   indices = [[39 15 42 35 14]]
#
# (41/49) Performing kNN on query 'beignets_1017820_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[3.5762787e-07 3.5380483e-02 3.9399922e-02 4.9156785e-02 4.9406946e-02]]
#   indices = [[40 15  2 13 12]]
#
# (42/49) Performing kNN on query 'apple_pie_1011328_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.04204404 0.04357457 0.04669625 0.05216044]]
#   indices = [[41 15 33 35  2]]
#
# (43/49) Performing kNN on query 'bread_pudding_1042213_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[2.3841858e-07 3.2313585e-02 3.7052453e-02 3.7823915e-02 3.8398087e-02]]
#   indices = [[42 15 43  2 20]]
#
# (44/49) Performing kNN on query 'bread_pudding_1084705_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.03705245 0.03958786 0.04365933 0.04376978]]
#   indices = [[43 42 15 34 10]]
#
# (45/49) Performing kNN on query 'beef_carpaccio_1044312_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.05412507 0.05882055 0.06124634 0.06453794]]
#   indices = [[44 37 38 36 14]]
#
# (46/49) Performing kNN on query 'baby_back_ribs_1074480_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.03282452 0.03722131 0.04112405 0.04223049]]
#   indices = [[45 34 20 25 16]]
#
# (47/49) Performing kNN on query 'beef_tartare_1031053_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.7881393e-07 4.0817440e-02 5.9576809e-02 5.9658289e-02 6.3292384e-02]]
#   indices = [[46 15 17  2 43]]
#
# (48/49) Performing kNN on query 'beet_salad_1030522_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[0.         0.05051208 0.05810994 0.05854696 0.05882198]]
#   indices = [[47 20 14 34 43]]
#
# (49/49) Performing kNN on query 'beet_salad_1071243_resized'...
#   x_test_kNN.shape = (1, 1352)
#   distances = [[1.7881393e-07 4.1710973e-02 4.7275305e-02 5.3531110e-02 5.7547092e-02]]
#   indices = [[48 25 11 34 45]]
